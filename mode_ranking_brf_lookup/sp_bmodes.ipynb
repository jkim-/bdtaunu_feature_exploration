# %%
# %matplotlib inline
import numpy as np
import pandas as pd
import networkx as nx
from networkx.drawing.nx_agraph import to_agraph
import pygraphviz
import ast
from IPython.display import Image, HTML
from collections import defaultdict
import operator

# %%
HTML('''<script>
code_show=true; 
function code_toggle() {
 if (code_show){
 $('div.input').hide();
 } else {
 $('div.input').show();
 }
 code_show = !code_show
} 
$( document ).ready(code_toggle);
</script>
The raw code for this IPython notebook is by default hidden for easier reading.
To toggle on/off the raw code, click <a href="javascript:code_toggle()">here</a>.''')
# Out:
# <script>
# code_show=true;
# function code_toggle() {
#  if (code_show){
#  $('div.input').hide();
#  } else {
#  $('div.input').show();
#  }
#  code_show = !code_show
# }
# $( document ).ready(code_toggle);
# </script>
# The raw code for this IPython notebook is by default hidden for easier reading.
# To toggle on/off the raw code, click <a href="javascript:code_toggle()">here</a>.

# %%
sp1235 = pd.read_csv('sp1235_graphs.csv', index_col='eid', tupleize_cols=True)
sp1237 = pd.read_csv('sp1237_graphs.csv', index_col='eid', tupleize_cols=True)

# %%
def StrToList(str):
    if str.startswith("{") and str.endswith("}"):
        return [ast.literal_eval(x) for x in str[1:-1].strip().split(",")]
    else:
        raise "StrToList error: str must be in the form {1,2,3,...}"

# %%
def DrawGraph(cur_record):
    n_nodes = cur_record.mc_n_vertices
    lund_list = StrToList(cur_record.mc_lund_id)
    from_list = StrToList(cur_record.mc_from_vertices)
    to_list = StrToList(cur_record.mc_to_vertices)
    G = nx.DiGraph()
    G.add_nodes_from([(x,{'label':y}) for x,y in zip(range(0, n_nodes), lund_list)])
    G.add_edges_from([(x,y) for x,y in zip(from_list,to_list)])
    return G

# %%
cur_eid = 28133632
cur_record = sp1235.loc[cur_eid]
G = DrawGraph(cur_record)
A = to_agraph(G)
A.draw('tmp.png', prog='dot')
Image(filename='tmp.png')

# %%
def GetBDecays(cur_record):
    n_nodes = cur_record.mc_n_vertices
    lund_list = StrToList(cur_record.mc_lund_id)
    from_list = StrToList(cur_record.mc_from_vertices)
    to_list = StrToList(cur_record.mc_to_vertices)

    b_indexes = [i for i,x in enumerate(lund_list) if abs(x) == 521 or abs(x) == 511]
    b_daus = []
    if len(b_indexes) != 2:
        raise AssertionError("There should be two B's in the event", len(b_indexes))
    for b in b_indexes:
        b_from = [i for i,x in enumerate(from_list) if x == b]
        b_daus.append(tuple(sorted([abs(lund_list[to_list[i]]) for i in b_from])))
    return b_daus

# %%
pdt = pd.read_table('pdt.dat', sep='\s+', names=['particle','lundID'])
lund_dict = dict([(i, name) for i, name in zip(pdt.lundID, pdt.particle)])

# %%
sp1235_b_decays = defaultdict(int)
for _, row in sp1235.head(1000).iterrows():
    b_modes =  GetBDecays(row)
    sp1235_b_decays[b_modes[0]] += 1
    sp1235_b_decays[b_modes[1]] += 1

# %%
b_decays_list_sp1235 = []
b_decays_count_sp1235 = []
for k,v in sorted(sp1235_b_decays.items(), key=operator.itemgetter(1), reverse = True):
    b_decays_list_sp1235.append(list(k))
    b_decays_count_sp1235.append(v)

# %%
sp1237_b_decays = defaultdict(int)
for _, row in sp1237.head(1000).iterrows():
    b_modes =  GetBDecays(row)
    sp1237_b_decays[b_modes[0]] += 1
    sp1237_b_decays[b_modes[1]] += 1

# %%
b_decays_list_sp1237 = []
b_decays_count_sp1237 = []
for k,v in sorted(sp1237_b_decays.items(), key=operator.itemgetter(1), reverse = True):
    b_decays_list_sp1237.append(list(k))
    b_decays_count_sp1237.append(v)

# %%
b_decays_names_sp1235 = [[lund_dict[x] for x in decay] for decay in b_decays_list_sp1235]
b_decays_names_sp1237 = [[lund_dict[x] for x in decay] for decay in b_decays_list_sp1237]
for d, c, e, f in zip(b_decays_names_sp1235, b_decays_count_sp1235, b_decays_names_sp1237, b_decays_count_sp1237):
    print '{0:40} {1:10} {2:40} {3}'.format(d,c,e,f)
# Out:
# ['mu-', 'nu_mu', 'D*0']                         189 ['mu-', 'nu_mu', 'D*+']                  218
# ['e-', 'nu_e', 'D*0']                           175 ['e-', 'nu_e', 'D*+']                    137
# ['mu-', 'nu_mu', 'D0']                           81 ['e-', 'nu_e', 'gamma', 'D*+']           80
# ['e-', 'nu_e', 'gamma', 'D*0']                   66 ['mu-', 'nu_mu', 'D+']                   70
# ['e-', 'nu_e', 'D0']                             55 ['e-', 'nu_e', 'D+']                     51
# ['tau-', 'nu_tau', 'D*0']                        45 ['D*+', 'D_s*+']                         51
# ['D*0', 'D_s*+']                                 37 ['tau-', 'nu_tau', 'D*+']                47
# ['D*0', 'D_s+']                                  32 ['mu-', 'nu_mu', 'gamma', 'D*+']         41
# ['e-', 'nu_e', 'gamma', 'D0']                    29 ['mu-', 'nu_mu', "D'_1+"]                27
# ['D*0', 'a_1+']                                  29 ['e-', 'nu_e', 'gamma', 'D+']            26
# ['mu-', 'nu_mu', "D'_10"]                        29 ['D+', 'D_s*+']                          25
# ['D0', 'D_s+']                                   28 ['K+', 'D*+', 'D*0']                     25
# ['mu-', 'nu_mu', 'gamma', 'D*0']                 28 ['D*+', 'D_s+']                          23
# ['pi0', 'pi+', 'pi+', 'D*+']                     26 ['K+', 'D+', 'D*0']                      20
# ['mu-', 'nu_mu', 'D_10']                         24 ['e-', 'nu_e', 'gamma', 'gamma', 'D*+']  19
# ['D0', 'D_s*+']                                  23 ['D+', 'D_s+']                           17
# ['rho+', 'D0']                                   23 ['D*+', 'D_s1+']                         17
# ['e-', 'nu_e', 'gamma', 'gamma', 'D*0']          21 ['mu-', 'nu_mu', 'D_1+']                 16
# ['tau-', 'nu_tau', 'D0']                         21 ['e-', 'nu_e', 'D_1+']                   16
# ['mu-', 'nu_mu', 'D_0*0']                        21 ['e-', 'nu_e', "D'_1+"]                  16
# ['e-', 'nu_e', "D'_10"]                          19 ['D*+', 'a_1+']                          13
# ['rho+', 'D*0']                                  17 ['D_2*+', 'D_s*+']                       13
# ['e-', 'nu_e', 'D_0*0']                          16 ['e-', 'nu_e', 'gamma', "D'_1+"]         13
# ['mu-', 'nu_mu', 'gamma', 'D0']                  15 ['e-', 'nu_e', 'gamma', 'D_1+']          12
# ['e-', 'nu_e', 'D_10']                           14 ['mu-', 'nu_mu', 'gamma', 'D+']          12
# ['e-', 'nu_e', 'gamma', "D'_10"]                 13 ['mu-', 'nu_mu', 'D_0*+']                11
# ['K+', 'D*0', 'D*0']                             13 ['K0', 'D*+', 'D*+']                     11
# ['K+', 'D0', 'D*0']                              12 ['rho+', 'D+']                           11
# ['string']                                       11 ['rho+', 'D*+']                          10
# ['pi+', 'D*0']                                   11 ['e-', 'nu_e', 'D_0*+']                  10
# ['pi+', 'D+', 'D_s+']                            10 ['K*+', 'D+', 'D*0']                     10
# ['D0', 'a_1+']                                   10 ['D+', 'a_1+']                           9
# ['D*0', 'D_s1+']                                  9 ['K*0', 'D+', 'D*+']                     9
# ['pi+', 'pi+', 'pi+', 'D0']                       8 ['tau-', 'nu_tau', 'D+']                 9
# ['K*0', 'K+', 'D0']                               8 ['mu-', 'nu_mu', 'D_2*+']                9
# ['K*+', 'D*0', 'D*0']                             8 ['mu-', 'nu_mu', 'pi+', 'D0']            8
# ['pi0', 'rho+', 'D0']                             8 ['D+', 'D_s1+']                          8
# ['K*0', 'D+', 'D0']                               8 ['K+', 'D*+', 'D0']                      8
# ['e-', 'nu_e', 'gamma', 'gamma', 'D0']            7 ['D_2*+', 'D_s+']                        7
# ['e-', 'nu_e', 'D_2*0']                           7 ['K*0', 'D*+', 'D*+']                    7
# ['K+', 'D*+', 'D*+']                              7 ['tau-', 'nu_tau', 'D_2*+']              7
# ['K0', 'D*+', 'D*0']                              7 ['K*0', 'J/psi']                         7
# ['D_2*0', 'D_s+']                                 7 ['mu-', 'nu_mu', 'Xu+']                  7
# ['J/psi', 'K_1+']                                 7 ['pi+', 'omega', 'D*+']                  7
# ['K*+', 'D0', 'D*0']                              7 ['pi+', 'pi+', 'rho+', 'D+']             7
# ['gamma', 'pi0', 'pi+', 'pi+', 'D*+']             7 ['e-', 'nu_e', 'gamma', 'gamma', 'D+']   7
# ['K*+', 'D+', 'D*+']                              7 ['e-', 'nu_e', 'gamma', 'D_0*+']         7
# ['mu-', 'nu_mu', 'D_2*0']                         7 ['D_s*+', "D'_1+"]                       6
# ['K+', 'D+', 'D*+']                               7 ['pi+', 'omega', 'D+']                   6
# ['D*0', 'D_s0*+']                                 6 ['e-', 'nu_e', 'pi+', 'D0']              6
# ['D0', 'D_s1+']                                   6 ['D+', 'D_s0*+']                         6
# ['e-', 'nu_e', 'gamma', 'gamma', "D'_10"]          6 ['tau-', 'nu_tau', "D'_1+"]              6
# ['pi+', 'pi+', 'rho+', 'D0']                      6 ['K0', 'D+', 'D*+']                      6
# ['mu-', 'nu_mu', 'pi+', 'D+']                     6 ['J/psi', 'K_10']                        5
# ['pi+', 'D+', 'D_s*+']                            6 ['K*+', 'D+', 'D0']                      5
# ['K0', 'D+', 'D*0']                               5 ['rho0', 'rho+', 'D+']                   5
# ['tau-', 'nu_tau', "D'_10"]                       5 ['pi+', 'p+', 'Sigma_c0']                5
# ['D_2*0', 'D_s*+']                                5 ['pi0', 'pi+', 'D0', 'D_s+']             5
# ['pi+', 'D0']                                     5 ['K+', 'D+', 'D0']                       5
# ['pi0', 'rho0', 'pi+', 'D0']                      5 ['K*+', 'D*+', 'D*0']                    5
# ['pi0', 'pi+', 'pi+', 'rho+', 'D0']               5 ['pi+', 'pi+', 'D+', 'D_s+']             5
# ['pi+', 'K+', 'K+', 'D0']                         5 ['string']                               4
# ['K*0', 'K*+', 'D0']                              5 ['e-', 'nu_e', 'gamma', 'D_2*+']         4
# ['K*+', 'D0', 'D0']                               5 ['e-', 'nu_e', 'pi+', 'D*0']             4
# ['pi+', 'rho+', 'D*+']                            5 ['D_s+', 'D_1+']                         4
# ['D_s*+', 'D_10']                                 5 ['pi+', 'eta', 'D+']                     4
# ['D*+', 'Delta-', 'Delta+']                       4 ['pi+', 'D0', 'D_s*+']                   4
# ['e-', 'nu_e', 'gamma', 'D_10']                   4 ['K*0', 'D*0', 'D*0']                    4
# ['pi0', 'pi+', 'D+', 'D_s+']                      4 ['K*0', 'K*+', 'D*+']                    4
# ['pi+', 'pi+', 'D0', 'D_s+']                      4 ['pi+', 'pi+', 'D+', 'D_s*+']            4
# ['pi+', 'K+', 'D+', 'D0']                         4 ['pi+', 'D0', 'D_s+']                    4
# ['e-', 'nu_e', 'gamma', 'D_2*0']                  4 ['K*0', 'K+', 'D*+']                     4
# ['mu-', 'nu_mu', 'gamma', 'D_0*0']                4 ['e-', 'nu_e', 'Xu+']                    4
# ['pi+', 'eta', 'D0']                              4 ['pi+', 'D*+']                           4
# ['mu-', 'nu_mu', 'pi0', 'D0']                     4 ['pi0', 'pi0', 'D+', 'D_s+']             4
# ['pi0', 'D0', 'D_s*+']                            4 ['e-', 'nu_e', 'D_2*+']                  4
# ['e-', 'nu_e', 'pi0', 'D0']                       4 ['pi0', 'pi+', 'pi+', 'D*0']             4
# ['pi+', 'pi+', 'D0', 'D_s*+']                     4 ['gamma', 'rho+', 'D*+']                 4
# ['pi+', 'omega', 'D0']                            4 ['K*0', 'D+', 'D+']                      4
# ['rho0', 'rho+', 'D0']                            4 ['D0', 'p+', 'Delta+']                   4
# ['D0', 'p+', 'Delta++']                           4 ['rho+', 'omega', 'D*+']                 4
# ['K+', 'D0', 'D0']                                4 ['D*+', 'D_s0*+']                        3
# ['rho+', 'omega', 'D0']                           4 ['K*0', 'eta_c']                         3
# ['mu-', 'nu_mu', 'gamma', 'D_2*0']                4 ['D+', 'Delta-', 'Delta0']               3
# ['K0', 'D+', 'D0']                                4 ['mu-', 'nu_mu', 'pi0', 'D+']            3
# ['pi+', 'rho+', 'D+']                             3 ['pi0', 'pi+', 'omega', 'D*+']           3
# ['mu-', 'nu_mu', 'gamma', 'D_10']                 3 ['gamma', 'D+', 'D_s+']                  3
# ['mu-', 'nu_mu', 'gamma', "D'_10"]                3 ['K0', 'D*0', 'D*0']                     3
# ['K+', 'D0']                                      3 ['rho+', 'D_2*+']                        3
# ['tau-', 'nu_tau', 'D_0*0']                       3 ['pi0', 'pi+', 'D*+']                    3
# ['gamma', 'pi+', 'pi+', 'pi+', 'D0']              3 ['mu-', 'nu_mu', 'gamma', 'pi+', 'D0']   3
# ['pi0', 'rho+', 'omega', 'D0']                    3 ['mu-', 'nu_mu', 'gamma', "D'_1+"]       3
# ['K0', 'D*+', 'D0']                               3 ['mu-', 'nu_mu', 'gamma', 'D_1+']        3
# ['e-', 'nu_e', 'gamma', 'D_0*0']                  3 ['e-', 'nu_e', 'gamma', 'Xu+']           3
# ['pi0', 'pi0', 'pi+', 'pi+', 'rho+', 'D0']          3 ['pi0', 'rho0', 'pi+', 'D+']             3
# ['rho+', 'K+', 'D*+', 'D0']                       3 ['pi0', 'pi+', 'pi+', 'rho+', 'D+']      3
# ['pi+', 'Delta++', 'Sigma_c*0']                   3 ['rho+', 'omega', 'D+']                  3
# ['K*0', 'D+', 'D*0']                              3 ['pi+', 'rho+', 'rho+', 'D+']            3
# ['K*0', 'D*+', 'D*0']                             3 ['gamma', 'pi+', 'eta', 'D+']            3
# ['e-', 'nu_e', 'gamma', 'Xu0']                    3 ['pi+', 'D+']                            3
# ['pi0', 'pi+', 'eta', 'D0']                       3 ['rho+', 'eta', 'D+']                    3
# ['pi0', 'pi+', 'omega', 'D0']                     3 ['K0', 'D+', 'D+']                       3
# ['pi0', 'pi+', 'D+', 'D_s*+']                     3 ['K*0', 'eta_c(2S)']                     3
# ['mu-', 'nu_mu', 'pi+', 'D*+']                    3 ['gamma', 'pi0', 'pi+', 'pi+', 'rho+', 'D*+'] 3
# ['K*+', 'eta_c']                                  3 ['pi0', 'D+', 'D_s+']                    3
# ['pi+', 'Delta++', 'Sigma_c*++']                  3 ['K0', 'D0', 'D*0']                      3
# ['pi0', 'pi0', 'rho+', 'D*0']                     3 ['pi+', 'K+', 'K+', 'D*+']               3
# ['e-', 'nu_e', 'pi+', 'D+']                       3 ['e-', 'nu_e', 'gamma', 'gamma', 'gamma', 'D*+'] 3
# ['K0', 'K+', 'D0']                                3 ['pi0', 'pi0', 'rho+', 'D+']             3
# ['phi', 'D0', 'D_s+']                             2 ['pi0', 'rho0', 'rho+', 'D+']            2
# ['D_s+', 'D_10']                                  2 ['gamma', 'rho+', 'omega', 'D*+']        2
# ['pi+', 'D0', 'p+', 'p+']                         2 ['pi0', 'K0', 'D+', 'D*+']               2
# ['D0', 'Delta0', 'Delta+']                        2 ['rho0', 'pi+', 'pi+', 'rho+', 'D*+']    2
# ['pi+', 'pi+', 'K+', 'chi_c2']                    2 ['pi0', 'K0', 'D+', 'D+']                2
# ['pi0', 'rho+', 'K+', 'D*+']                      2 ['pi0', 'pi+', 'omega', 'D+']            2
# ['D_s+', "D'_10"]                                 2 ['K*+', 'D*+', 'D0']                     2
# ['pi0', 'rho+', 'eta', 'D0']                      2 ['K0', 'K+', 'D*+']                      2
# ['rho+', 'eta', 'D0']                             2 ['omega', 'K*+', 'D+']                   2
# ['rho0', 'pi+', 'D0']                             2 ['D0', 'p+', 'p+']                       2
# ['pi+', 'pi+', 'D+']                              2 ['mu-', 'nu_mu', 'gamma', 'gamma', 'D*+'] 2
# ['mu-', 'nu_mu', 'gamma', 'Xu0']                  2 ['pi0', 'pi+', 'pi+', 'rho+', 'eta', 'D+'] 2
# ['pi+', 'omega', 'D*0']                           2 ['K*0', 'psi(2S)']                       2
# ['pi0', 'pi0', 'pi+', 'D0']                       2 ['gamma', 'pi0', 'pi+', 'pi+', 'rho+', 'D+'] 2
# ['pi+', 'D_10']                                   2 ['D+', 'Delta0', 'Delta+']               2
# ['rho+', 'Delta++', 'Sigma_c++']                  2 ['pi0', 'pi0', 'D+', 'D_s*+']            2
# ['D_s*+', "D'_10"]                                2 ['K*0', 'D0', 'D*0']                     2
# ['gamma', 'pi+', 'pi+', 'D0', 'D_s*+']            2 ['K0', 'D0', 'D_10']                     2
# ['pi0', 'pi+', 'pi+', 'D+']                       2 ['pi0', 'pi0', 'pi0', 'pi+', 'rho+', 'rho+', 'D+'] 2
# ['pi+', 'K*+', 'D+', 'D*0']                       2 ['gamma', 'K*0', 'K+', 'D+']             2
# ['pi+', 'eta', 'omega', 'D*0']                    2 ['pi0', 'pi+', 'D_1+']                   2
# ['K*0', 'K*+', 'D*0']                             2 ['pi0', 'pi+', 'eta', 'D*+']             2
# ['K*0', 'D*+', 'D0']                              2 ['rho0', 'K0', 'K+', 'D+']               2
# ['rho+', 'eta', 'D*0']                            2 ['pi+', 'pi+', 'pi+', 'K*+', 'D0', 'D0'] 2
# ['e-', 'nu_e', 'gamma', 'gamma', 'gamma', 'D0']          2 ['pi0', 'rho0', 'pi+', 'eta', 'D+']      2
# ['pi0', 'rho0', 'rho+', 'D0']                     2 ['tau-', 'nu_tau', 'gamma', 'D+']        2
# ['tau-', 'nu_tau', 'D_10']                        2 ['K0', 'K+', 'D+']                       2
# ['pi0', 'pi+', 'pi+', 'rho+', 'D*0']              2 ['pi0', 'pi+', 'rho+', 'rho+', 'D*+']    2
# ['K*+', 'Delta++', 'Omega_c*0']                   2 ['rho0', 'pi+', 'D+']                    2
# ['pi+', 'pi+', 'rho+', 'D*0']                     2 ['K_L0', 'eta_c']                        2
# ['gamma', 'D0', 'a_1+']                           2 ['D*0', 'p+', 'p+']                      2
# ['pi0', 'pi0', 'pi+', 'omega', 'D0']              2 ['e-', 'nu_e', 'gamma', 'gamma', 'D_2*+'] 2
# ['pi0', 'pi0', 'D0', 'D_s*+']                     2 ['e-', 'nu_e', 'gamma', 'gamma', 'gamma', 'D+'] 2
# ['pi0', 'pi0', 'pi0', 'pi+', 'D0']                2 ['pi0', 'K*0', 'K+', 'D*+']              2
# ['K+', 'chi_c1']                                  2 ['pi0', 'rho0', 'pi+', 'D*+']            2
# ['D*0', 'n0', 'Delta+']                           2 ['pi+', 'pi+', 'rho+', 'D*+']            2
# ['pi+', 'D0', 'n0', 'n0']                         2 ['pi0', 'pi0', 'pi+', 'D*+']             2
# ['e-', 'nu_e', 'pi+', 'D*+']                      2 ['pi0', 'pi0', 'pi+', 'D+']              2
# ['pi0', 'pi+', 'rho+', 'rho+', 'D0']              2 ['pi0', 'pi+', 'pi+', 'D0']              2
# ['rho+', 'D_10']                                  2 ['rho+', "D'_1+"]                        2
# ['rho+', 'p+', 'Sigma_c*+']                       2 ['pi+', 'rho+', 'rho+', 'D*+']           2
# ['pi0', 'Delta++', 'Sigma_c*+']                   2 ['pi0', 'pi+', "D'_1+"]                  2
# ['rho0', 'pi+', 'D_2*0']                          2 ['rho+', 'K0', 'D+', 'D*0']              2
# ['pi0', 'D0', 'D_s+']                             2 ['pi0', 'D+', 'n0', 'p+']                2
# ['pi+', 'K+', 'K*+', 'D0']                        2 ['pi+', 'K*0', 'D+', 'D0']               2
# ['gamma', 'pi+', 'D+', 'D_s*+']                   2 ['gamma', 'pi+', 'eta', 'D*+']           2
# ['pi+', 'K+', 'D+', 'D*0']                        2 ['pi0', 'pi+', 'eta', 'D+']              2
# ['K0', 'K*+', 'D0']                               2 ['gamma', 'rho+', 'D_2*+']               2
# ['e-', 'nu_e', 'gamma', 'gamma', 'gamma', 'D*0']          2 ['D0', 'Delta+', 'Sigma+']               2
# ['pi0', 'pi+', 'pi+', 'pi+', 'D0']                2 ['pi0', 'pi+', 'K+', 'D+', 'D*+']        2
# ['rho+', 'D_2*0']                                 2 ['D*0', 'p+', 'Delta+']                  2
# ['K*+', 'D*0']                                    2 ['pi+', 'D*+', 'a_10']                   2
# ['gamma', 'D0', 'D_s*+']                          2 ['D_s*+', 'D_1+']                        2
# ['pi0', 'rho+', 'omega', 'D*0']                   2 ['pi+', 'pi+', 'D+', 'n0', 'p+']         2
# ['pi0', 'pi+', 'K+', 'K+', 'D*0']                 2 ['pi+', 'K*+', 'D0', 'D0']               2
# ['K*0', 'K+', 'D*0']                              2 ['pi0', 'pi+', 'K+', 'K*+', 'D+']        2
# ['pi0', 'K+', 'D+', 'D+']                         2 ['pi0', 'pi+', 'D*+', 'b_10']            2
# ['pi+', 'Delta++', 'Sigma_c++']                   2 ['omega', 'K0', 'D+', 'D*+']             2
# ['pi0', 'K*0', 'K+', 'D_0*0']                     2 ['K*0', 'psi(3770)']                     2
# ['pi+', 'pi+', 'pi+', 'D*0']                      1 ['pi0', 'pi+', 'K+', 'K+', 'D+']         2
# ['mu-', 'nu_mu', 'pi0', 'D*0']                    1 ['pi+', 'K+', 'D0', 'D*0']               2
# ['pi+', 'pi+', 'K*0', 'K+', 'D0']                 1 ['gamma', 'pi+', 'pi+', 'rho+', 'D*+']   2
# ['rho+', 'D0', 'f_0']                             1 ['pi0', 'K*+', 'D+', 'D0']               2
# ['rho0', 'pi+', 'pi+', 'K*0', 'D*0', 'a_0+']          1 ['pi+', 'pi+', 'pi+', 'omega', 'D+']     2
# ['rho+', 'D0', 'D0']                              1 ['rho0', 'Delta0', 'Sigma_c0']           2
# ['a_2+', 'K0', 'K0', 'D0']                        1 ['gamma', 'D*0', 'p+', 'Delta+']         2
# ['gamma', 'pi0', 'pi+', 'K+', 'K+', 'D0']          1 ['pi+', 'K+', 'K+', 'D+']                2
# ['K0', 'K+', 'K+', 'K+', 'D0']                    1 ['pi+', 'K+', 'D+', 'D*+']               2
# ['D*+', 'D*0']                                    1 ['pi+', 'K0', 'K0', 'D+']                2
# ['pi0', 'K*+', 'D+', 'D_0*+']                     1 ['rho+', 'n0', 'Lambda_c+']              2
# ['pi0', 'pi+', 'pi+', 'K+', 'D*0', 'D*0']          1 ['e-', 'nu_e', 'gamma', 'gamma', "D'_1+"] 2
# ['rho0', 'K0', 'K*0', 'K+']                       1 ['rho0', 'pi+', 'omega', 'D+']           2
# ['Sigma*+', "Xi'_c+", 'b_1+']                     1 ['pi0', 'D+', 'D_s*+']                   2
# ['gamma', 'pi+', 'rho+', 'rho+', 'D*0']           1 ['pi0', 'K*0', 'K*+', 'D*+']             1
# ['gamma', 'pi+', 'pi+', 'D*+']                    1 ['mu-', 'nu_mu', 'gamma', 'gamma', "D'_1+"] 1
# ['rho0', 'omega', 'K+', 'D0']                     1 ['pi+', 'D+', 'f_0']                     1
# ['gamma', 'K0', 'D+', 'D*0']                      1 ['pi0', 'K0', 'K0', 'D*+', 'D_s*+']      1
# ['pi+', 'pi+', 'pi+', 'rho+', 'rho+', 'omega']          1 ['pi+', 'K*0', 'D_s+', 'n0', 'n0']       1
# ['pi+', 'rho+', 'K+', 'K*+', 'K*+']               1 ['pi+', 'pi+', 'pi+', 'D+']              1
# ['rho+', 'Delta++', 'Sigma_c*0']                  1 ['pi0', 'rho+', 'K0', 'K0', 'D*+']       1
# ['pi0', 'p+', 'Sigma_c0']                         1 ['rho0', 'n0', 'Sigma_c0']               1
# ['pi0', 'pi0', 'K0', 'K0', 'D0', 'D_s*+']          1 ['pi0', 'pi+', 'D_0*+']                  1
# ['pi0', 'pi+', 'rho+', 'K*+', 'J/psi']            1 ['tau-', 'nu_tau', 'D_0*+']              1
# ['gamma', 'pi+', 'K*0', 'D_s+', 'D_s+']           1 ['rho+', 'D*+', 'h_1']                   1
# ['rho+', 'rho+', 'D0', 'a_0+']                    1 ['rho0', 'K0', 'eta_c']                  1
# ['pi0', 'rho+', 'K+', 'D+', 'D0']                 1 ['K0', 'K*+', 'D0', 'D_s+']              1
# ['pi+', 'K*+', 'D+', 'D0']                        1 ['pi0', 'rho0', 'pi+', 'D+', 'b_10']     1
# ['pi+', 'eta', 'D*0']                             1 ['D+', 'D+', 'K_10']                     1
# ['pi+', 'eta', 'D_2*0']                           1 ['rho+', 'p+', 'Sigma_c++']              1
# ['pi+', 'K+', 'D*+', 'D*0']                       1 ['gamma', 'pi+', 'pi+', 'eta', 'K0', 'D+', 'D*+'] 1
# ['gamma', 'pi0', 'rho+', 'D0']                    1 ['pi0', 'pi+', 'pi+', 'pi+', 'D+', 'f_0'] 1
# ['pi0', 'pi+', 'K*+', 'K*+', 'D*0']               1 ['K0', 'D+', "D'_1+"]                    1
# ['K0', 'K*+', 'D*0']                              1 ['K*0', 'Lambda0', 'Sigma_c0']           1
# ['pi+', 'K0', 'eta_c']                            1 ['pi0', 'rho0', 'D0', 'n0', 'Delta0']    1
# ['pi0', 'pi0', 'rho0', 'pi+', 'pi+', 'pi+', 'eta', 'omega', 'D0']          1 ['pi0', 'rho0', 'pi+', 'pi+', 'pi+', 'pi+', 'K0', 'K+', 'D*+'] 1
# ['e-', 'nu_e', 'pi0', 'D*0']                      1 ['gamma', 'K0', 'D+', 'D*+']             1
# ['omega', 'K*0', 'K+', 'D0']                      1 ['pi+', 'pi+', 'K0', 'K*+', 'D+']        1
# ['mu-', 'nu_mu', 'gamma', 'gamma', 'D*0']          1 ['pi0', 'rho0', 'pi+', 'D+', 'f_1']      1
# ['omega', 'K+', 'K*+', 'D_s+']                    1 ['pi0', 'K*0', 'K+', 'D+']               1
# ['pi+', 'D*+', 'D_s*+']                           1 ['pi+', 'omega', 'omega', 'D*+']         1
# ['mu-', 'nu_mu', 'gamma', 'gamma', 'D0']          1 ['omega', 'Delta0', 'Sigma_c*0']         1
# ['phi', 'D*0', 'D_s+']                            1 ['gamma', 'pi+', 'omega', 'D_1+']        1
# ['pi0', 'pi+', 'pi+', 'rho+', 'omega', 'p+', 'p+']          1 ['pi0', 'pi0', 'rho0', 'D0']             1
# ['pi0', 'rho0', 'pi+', 'D*0']                     1 ['pi+', 'omega', 'omega', 'D+']          1
# ['rho0', 'pi+', 'pi+', 'rho+', 'D*0']             1 ['rho0', 'Delta+', 'Sigma_c*+']          1
# ['pi0', 'pi+', 'pi+', 'D*+', 'D0']                1 ['rho+', 'Sigma0', 'Xi_c+']              1
# ['pi+', 'D*0', 'b_10']                            1 ['rho0', 'pi+', 'D*+']                   1
# ['pi+', 'pi+', 'D*0', 'a_1+']                     1 ['pi0', 'rho+', 'D_0*+']                 1
# ['e-', 'nu_e', 'gamma', 'pi+', 'D+']              1 ['pi0', 'D*+', 'b_1+']                   1
# ['rho+', 'K+', 'Delta++', 'Lambda_c+']            1 ['pi+', 'pi+', 'K*0', 'K+', 'D+']        1
# ['pi+', 'Delta+', 'Sigma_c*+']                    1 ['gamma', 'pi+', 'pi+', 'rho+', 'K+', 'a_00', 'D_10'] 1
# ['pi+', 'K*0', 'J/psi']                           1 ['D*+', 'Delta-', 'Delta0']              1
# ['pi+', 'K0', 'K*+', 'D_s*+', 'a_10']             1 ['K*0', 'chi_c0']                        1
# ['pi+', 'eta', 'D_10']                            1 ['rho0', 'pi+', 'pi+', 'pi+', 'pi+', 'rho+', 'D*+'] 1
# ['gamma', 'pi+', 'D*0', 'f_1']                    1 ['gamma', 'rho0', 'rho+', 'D+']          1
# ['gamma', 'K0', 'D*+', 'D*0']                     1 ['pi+', 'pi+', 'pi+', 'pi+', 'rho+', 'D*+'] 1
# ['pi0', 'pi+', 'rho+', 'D*+', 'n0', 'n0']          1 ['gamma', 'rho+', 'phi', 'D_s+']         1
# ['gamma', 'pi0', 'pi+', 'eta', 'D0']              1 ['pi+', 'K+', 'K*+', 'D+']               1
# ['D+', 'Delta++', 'Lambda0']                      1 ['K0', 'D_s+', 'D_1+']                   1
# ['rho0', 'pi+', 'eta', 'D*0', 'f_0']              1 ['rho+', 'D+', 'f_0']                    1
# ['pi+', 'p+', 'Xi_c*+']                           1 ['mu-', 'nu_mu', 'rho+']                 1
# ['pi+', 'D*0', 'p+', 'p+']                        1 ['pi0', 'rho0', 'pi+', 'pi+', 'pi+', 'K+', 'K+', 'D+'] 1
# ['rho+', "D'_10"]                                 1 ['pi0', 'pi0', 'rho0', 'rho+', 'D*+']    1
# ['D+', 'D0', "K'_10"]                             1 ['gamma', 'pi+', 'pi+', 'pi+', 'D+']     1
# ['e-', 'nu_e', 'gamma', 'gamma', 'Xu0']           1 ['mu-', 'nu_mu', 'gamma', 'D_0*+']       1
# ['pi0', 'rho0', 'pi+', 'D0', 'p+', 'p+']          1 ['gamma', 'pi0', 'pi+', 'D+', 'f_0']     1
# ['pi+', 'pi+', 'pi+', 'omega', 'D0']              1 ['e-', 'nu_e', 'gamma', 'gamma', 'gamma', 'D_1+'] 1
# ['pi0', 'pi0', 'K0', 'K*+', 'D*0']                1 ['pi0', 'pi+', 'K*0', 'D+', 'D*0']       1
# ['pi0', 'pi0', 'pi+', 'pi+', 'pi+', 'D*0']          1 ['K0', 'D_s+', "D'_s1+"]                 1
# ['rho+', 'Delta++', 'Sigma_c*++']                 1 ['pi+', 'pi+', 'K0', 'D*0', 'D*0']       1
# ['pi+', 'rho+', 'rho+', 'D0']                     1 ['gamma', 'pi0', 'pi0', 'pi+', 'pi+', 'pi+', 'D*+'] 1
# ['D*+', 'Delta0', 'Delta++']                      1 ['pi0', 'rho0', 'pi+', 'pi+', 'rho+', 'D*+', 'a_00'] 1
# ['pi+', 'K+', 'K*+', 'D_0*0']                     1 ['D+', 'D+', 'K_0*0']                    1
# ['D*0', 'Delta0', 'Delta+']                       1 ['gamma', 'D+', 'a_1+']                  1
# ['pi+', 'pi+', 'K0', 'K+', 'K+', 'D_s+']          1 ['gamma', 'pi+', 'rho+', 'K*0', 'K+', 'D+'] 1
# ['pi+', 'D0', 'D*0', 'K_0*0']                     1 ['gamma', 'gamma', 'pi0', 'pi+', 'pi+', 'rho+', 'D+'] 1
# ['pi+', 'pi+', 'rho+', 'D_10']                    1 ['gamma', 'pi+', 'pi+', 'rho+', 'D+']    1
# ['pi0', 'K+', 'D0', 'D0']                         1 ['p+', 'Delta+', "D'_10"]                1
# ['pi0', 'K+', 'D0']                               1 ['rho0', 'pi+', 'pi+', 'pi+', 'D+']      1
# ['gamma', 'pi+', 'pi+', 'pi+', 'eta', 'D0']          1 ['gamma', 'pi0', 'pi+', 'D_1+']          1
# ['rho+', 'omega', 'D*0']                          1 ['pi+', 'pi+', 'pi+', 'rho+', 'K0', 'K*0', 'D*0'] 1
# ['pi0', 'pi+', 'K0', 'K+', 'K+']                  1 ['K_L0', 'J/psi']                        1
# ['D+', 'D*+', 'K_0*+']                            1 ['rho0', 'K*+', 'D+', "K'_10"]           1
# ['pi0', 'pi+', 'omega', 'omega']                  1 ['rho+', 'omega', 'D_0*+']               1
# ['pi0', 'rho+', 'f_2', 'D0']                      1 ['pi0', 'pi0', 'pi0', 'pi+', 'pi+', 'pi+', 'K0', 'D*+', 'D0'] 1
# ['rho0', 'pi+', 'K0', 'D0', 'D0']                 1 ['pi+', 'eta', 'D*+', 'a_10']            1
# ['pi0', 'pi0', 'pi+', 'eta', 'D0']                1 ['rho+', 'K+', 'D0', 'D0']               1
# ['rho+', 'D+', 'D_s+']                            1 ['pi+', 'omega', 'D_0*+']                1
# ['Delta+', 'Delta++', 'D_0*0']                    1 ['e-', 'nu_e', 'gamma', 'gamma', 'gamma', "D'_1+"] 1
# ['K+', 'J/psi']                                   1 ['pi+', 'p+', 'p+', 'D_1+']              1
# ['pi0', 'pi+', 'K+', 'K*+', 'D*0']                1 ['eta', 'D+', 'D*+']                     1
# ['K*+', 'chi_c1']                                 1 ['rho0', 'pi+', 'omega', "D'_1+"]        1
# ['pi+', 'pi+', 'pi+', 'omega', 'D*0']             1 ['pi+', 'pi+', 'pi+', 'pi+', 'rho+', 'omega', 'D+'] 1
# ['rho+', 'D0', 'h_1']                             1 ['pi+', 'pi+', 'K*0', 'D*0', 'D*0']      1
# ['gamma', 'pi+', 'rho+', 'omega', 'D+']           1 ['gamma', 'K+', 'D*+', 'D*0']            1
# ['pi0', 'pi0', 'pi+', 'f_2', 'D*0']               1 ['gamma', 'rho+', 'eta', 'D*+']          1
# ['omega', 'K0', 'D+', 'D0']                       1 ['pi0', 'pi0', 'pi+', 'pi+', 'rho+', 'D+'] 1
# ['gamma', 'rho+', 'eta', 'D*0']                   1 ['pi0', 'pi+', 'pi+', 'eta', 'omega']    1
# ['gamma', 'pi0', 'pi+', 'D_10']                   1 ['pi0', 'pi0', 'rho0', 'pi+', 'pi+', 'eta', 'K0', 'K+', 'D*+'] 1
# ['rho0', 'pi+', 'pi+', 'rho+', 'D0']              1 ['gamma', 'pi0', 'pi+', 'pi+', 'D0']     1
# ['pi0', 'D0', 'n0', 'Delta+']                     1 ['phi', 'D+', 'D_s+']                    1
# ['pi0', 'pi+', 'K0', 'D0', 'D*0']                 1 ['pi+', 'K+', 'D0']                      1
# ['K*+', 'Delta++', 'Sigma_c*++']                  1 ['pi+', 'pi+', 'rho+', 'D0', 'n0', 'p+'] 1
# ['rho+', 'K+', 'K_2*+', 'D0']                     1 ['pi+', 'pi+', 'rho+', 'D*+', 'D0']      1
# ['pi+', 'pi+', 'D_2*0', 'D_s+']                   1 ['rho+', 'D*0', 'D_s*+']                 1
# ['pi+', 'pi+', 'D0', 'n0', 'p+']                  1 ['omega', 'D*0']                         1
# ['gamma', 'pi+', 'eta', 'D0']                     1 ['K_2*0', 'D+', 'D+']                    1
# ['K*+', 'D_s*+', 'D_s*+']                         1 ['gamma', 'D+', 'D_s*+']                 1
# ['pi0', 'rho0', 'pi+', 'eta', 'D*0']              1 ['rho0', 'rho0', 'pi+', 'pi+', 'pi+', 'D+'] 1
# ['pi0', 'K+', 'phi', 'J/psi']                     1 ['gamma', 'pi+', 'p+', 'Sigma_c++']      1
# ['rho0', 'rho0', 'pi+', 'eta', 'D0']              1 ['eta', 'K*+', 'D+', 'D0']               1
# ['gamma', 'pi+', 'eta', 'D_2*0']                  1 ['pi+', 'pi+', 'K+', 'D+', 'D0']         1
# ['pi0', 'p+', 'Sigma_c*0']                        1 ['gamma', 'pi0', 'pi0', 'pi+', 'pi+', 'rho+', 'D+'] 1
# ['pi0', 'pi0', 'pi+', 'pi+', 'K0', 'K*+', 'D*0']          1 ['pi0', 'pi0', 'pi0', 'pi+', 'D*+']      1
# ['eta', 'K+', 'eta_c']                            1 ['pi0', 'rho0', 'pi+', 'pi+', 'rho+', 'D*+'] 1
# ['gamma', 'pi+', 'K+', 'K*+', 'D0']               1 ['pi+', 'pi+', 'pi+', 'eta', 'eta', 'D+'] 1
# ['e-', 'nu_e', 'gamma', 'gamma', 'gamma', 'D_2*0']          1 ['gamma', 'pi+', 'pi+', 'K+', 'D+', 'D*0'] 1
# ['e-', 'nu_e', 'gamma', 'gamma', 'D_0*0']          1 ['pi0', 'pi+', 'pi+', 'rho+', 'a_0+']    1
# ['gamma', 'Xsu']                                  1 ['pi0', 'pi+', 'eta', "D'_1+"]           1
# ['rho+', 'K0', 'K+', 'K*+']                       1 ['pi+', 'pi+', 'pi+', 'rho+', 'D+', "K'_1+"] 1
# ['pi0', 'pi+', 'pi+', 'omega', 'K0', 'K+', 'D0']          1 ['pi0', 'pi+', 'D+', 'n0', 'n0']         1
# ['pi+', 'rho+', 'K*0', 'K+', 'D0']                1 ['gamma', 'D_2*+', 'D_s+']               1
# ['e-', 'nu_e', 'rho0']                            1 ['K*0', 'phi', 'phi']                    1
# ['pi+', 'pi+', 'K*0', 'D*0', 'b_1+']              1 ['pi0', 'pi+', 'pi+', 'pi+', 'pi+', 'pi+', 'D+'] 1
# ['gamma', 'rho0', 'K+', 'D+', 'D+']               1 ['omega', 'K+', 'D+', 'D*0']             1
# ['gamma', 'D*0', 'Delta++', 'Sigma+']             1 ['rho+', 'K+', 'D+', 'D*+']              1
# ['omega', 'K0', 'D*+', 'D0']                      1 ['D*0', 'D_s+', 'b_1+']                  1
# ['gamma', 'K0', 'K+', 'D0']                       1 ['pi+', 'pi+', 'K0', 'eta_c']            1
# ['pi0', 'rho+', 'eta', 'D*0']                     1 ['gamma', 'gamma', 'pi0', 'D+', 'b_1+']  1
# ['gamma', 'pi+', 'pi+', 'rho+', 'D*0']            1 ['rho+', 'K+', 'D*+', 'D*+']             1
# ['rho0', 'rho+', 'omega', 'D0']                   1 ['D+', 'D+']                             1
# ['K+', 'chi_c0']                                  1 ['K*+', 'D*+', "K'_10"]                  1
# ['pi0', 'pi+', 'omega', 'K0', 'D0']               1 ['rho+', 'D0', 'D_s+']                   1
# ['gamma', 'rho0', 'pi+', 'D0']                    1 ['eta', 'K0', 'K*+', 'D+']               1
# ['omega', 'D*0', 'a_1+']                          1 ['pi0', 'Delta0', 'Sigma_c0']            1
# ['pi+', 'pi+', 'pi+', 'eta', 'D*0']               1 ['pi0', 'K*0', 'D+', 'D+']               1
# ['pi0', 'pi+', 'D0', 'p+', 'p+']                  1 ['pi0', 'rho0', 'rho+', 'omega', 'D+']   1
# ['gamma', 'pi0', 'Delta++', 'Sigma_c*+']          1 ['K+', 'phi', 'D+']                      1
# ['pi+', 'pi+', 'pi+', 'pi+', 'pi+', 'pi+', 'rho+', 'D*0']          1 ['pi+', 'D*+', 'a_00']                   1
# ['Sigma*+', 'Lambda_c+', 'K_0*+']                 1 ['D+', 'Delta-', 'n0']                   1
# ['pi0', 'pi+', 'K+', 'D+']                        1 ['D*+', 'Delta0', 'Sigma*-']             1
# ['pi+', 'D0', 'a_10']                             1 ['pi0', 'pi0', 'rho0', 'pi+', 'pi+', 'rho+', 'D+'] 1
# ['rho+', 'K0', 'K*0', 'D*0']                      1 ['rho0', 'rho0', 'pi+', 'D_1+']          1
# ['gamma', 'pi0', 'pi+', 'D+', 'D_s*+']            1 ['pi+', 'pi+', 'pi+', 'K*+', 'D+', 'D*+'] 1
# ['K+', 'eta_c']                                   1 ['gamma', 'pi+', 'pi+', 'D+', 'D_s+']    1
# ['gamma', 'K*+', 'J/psi']                         1 ['rho+', 'D*+', 'D0']                    1
# ['pi0', 'pi+', 'D0', 'Sigma-', 'Sigma-']          1 ['pi0', 'pi+', 'rho+', 'K0', 'K+', 'D+'] 1
# ['pi0', 'pi0', 'rho+', 'D0']                      1 ['pi+', 'K*+', 'D_s+', 'D_s*+']          1
# ['pi+', 'pi+', 'rho+', 'D0', 'f_0']               1 ['pi0', 'pi0', 'K0', 'K*+', 'D+']        1
# ['rho0', 'pi+', 'eta', 'D*0']                     1 ['K*+', 'Delta+', 'Sigma_c*++']          1
# ['gamma', 'gamma', 'pi0', 'pi+', 'pi+', 'pi+', 'pi+', 'D+']          1 ['rho0', 'K+', 'D*+', 'D0']              1
# ['pi+', 'K+', 'K*+', 'D*0']                       1 ['pi+', 'K0', 'D+', 'D0']                1
# ['pi+', 'rho+', 'D_2*0', 'b_1+']                  1 ['gamma', 'pi+', 'pi+', 'D+', 'n0', 'p+'] 1
# ['pi0', 'pi+', 'rho+', 'K+', 'f_1']               1 ['pi0', 'D+', 'D*+']                     1
# ['gamma', 'pi0', 'pi+', 'D*0']                    1 ['pi+', 'pi+', 'rho+', 'eta', 'D+']      1
# ['Delta++', 'Sigma_c*+', 'f_0']                   1 ['pi0', 'pi+', 'pi+', 'D*+', 'a_1+']     1
# ['e-', 'nu_e', 'gamma', 'gamma', 'gamma', 'D_0*0']          1 ['pi0', 'pi+', 'pi+', 'pi+', 'K*0', 'K*+'] 1
# ['gamma', 'pi+', 'eta', 'K+', 'D0', 'D_s+']          1 ['pi+', 'pi+', 'pi+', 'pi+', 'K*0', 'K+', 'D+'] 1
# ['K+', 'psi(2S)']                                 1 ['pi0', 'pi0', 'pi+', 'pi+', 'pi+', 'pi+', 'pi+', 'rho+', 'D*0'] 1
# ['K_2*+', 'D0', 'D0']                             1 ['pi0', 'pi+', 'pi+', 'rho+', 'D*+', 'h_1'] 1
# ['pi+', 'pi+', 'pi+', 'eta', 'D0']                1 ['pi0', 'pi0', 'pi0', 'pi+', 'rho+', 'D0'] 1
# ['gamma', 'D+', 'p+', 'Sigma*-']                  1 ['pi0', 'pi+', 'pi+', 'pi+', 'eta', 'D+'] 1
# ['e-', 'nu_e', 'gamma', 'gamma', 'gamma', 'pi+', 'D+']          1 ['gamma', 'rho+', 'eta', 'D+']           1
# ['pi+', 'K*+', 'D0', 'D_0*+']                     1 ['K*0', 'D0', "D'_10"]                   1
# ['rho0', 'eta', 'D*+', 'D0']                      1 ['pi0', 'pi+', 'f_2', 'D+']              1
# ['p+', 'Xi_c*0', 'f_0']                           1 ['gamma', 'pi+', 'pi+', 'D0']            1
# ['pi+', 'pi+', 'K+', 'D0', 'D*0']                 1 ['pi0', 'pi+', 'rho+', 'K+', 'D*+']      1
# ['pi+', 'pi+', 'K+', 'D+', 'D_0*+']               1 ['pi0', 'pi+', 'f_2', 'D*+']             1
# ['pi0', 'pi+', 'pi+', 'K+', 'D0', 'D0']           1 ['pi+', 'K+', 'psi(2S)']                 1
# ['K*0', 'D*0', "K'_1+"]                           1 ['gamma', 'pi0', 'pi+', 'K+', 'K*+', 'D+'] 1
# ['gamma', 'K+', 'D+', 'D*+']                      1 ['pi0', 'eta', 'D*0']                    1
# ['pi0', 'pi0', 'D0', 'n0', 'p+']                  1 ['pi+', 'K0', 'K0', 'K*0', 'K*0', 'K+']  1
# ['pi0', 'pi+', 'pi+', 'rho+', 'omega', 'D*0']          1 ['gamma', 'D*+', 'a_1+']                 1
# ['pi0', 'pi+', 'K*+', 'D*+', 'D*0']               1 ['K*0', 'n0', "Xi'_c0"]                  1
# ['pi0', 'rho+', 'D*0']                            1 ['mu-', 'nu_mu', 'gamma', 'pi+', 'D*0']  1
# ['pi+', 'pi+', 'pi+', 'K0', 'D0', 'D0']           1 ['rho0', 'K+', 'D_s*+']                  1
# ['Delta0', 'Delta+', 'D_10']                      1 ['omega', 'K0', 'K*+', 'D+']             1
# ["eta'", 'phi', 'D_s*+']                          1 ['pi+', 'D+', 'K_10']                    1
# ['D0', 'n0', 'Delta+']                            1 ['eta', 'K0', 'D+', 'D+']                1
# ['pi0', 'pi0', 'pi+', 'D*0']                      1 ['pi0', 'pi0', 'K0', 'K+', 'D+']         1
# ['Delta+', 'Sigma_c+', 'b_1+']                    1 ['pi0', 'rho+', 'D_2*+']                 1
# ['gamma', 'pi0', 'K*+', 'D0', 'D0']               1 ['rho0', 'rho0', 'pi+', 'pi+', 'pi+', 'pi+', 'K*+', 'D_s*+'] 1
# ['pi0', 'pi+', 'K*0', 'K*+', 'K*+']               1 ['eta', 'omega', 'D+', 'D*+']            1
# ['rho+', 'f_0', 'D_0*0']                          1 ['K*0', 'K+', 'D+']                      1
# ['pi+', 'pi+', 'D+', 'a_00']                      1 ['pi0', 'rho+', 'D+', 'f_0']             1
# ['rho0', 'D0', 'a_0+']                            1 ['D+', 'n0', 'p+']                       1
# ['pi0', 'pi0', 'rho0', 'pi+', 'K0', 'K0', 'D0']          1 ['pi0', 'pi0', 'pi+', 'pi+', 'K*0', 'D*0'] 1
# ['gamma', 'pi+', 'D*0']                           1 ['K0', 'Delta+', 'Lambda_c+']            1
# ['rho+', 'D*0', 'a_10']                           1 ['pi0', 'K0', 'K+', 'K+', 'J/psi']       1
# ['pi0', 'pi0', 'rho0', 'pi+', 'D0']               1 ['K+', 'Sigma*0', 'Sigma_c*+']           1
# ['rho0', 'pi+', 'pi+', 'pi+', 'K+', 'K+', 'D*0']          1 ['eta', 'K*0', 'K+', 'D*+']              1
# ['pi+', 'D+', 'D_s+', 'a_00']                     1 ['pi0', 'rho+', 'D+', 'p+', 'p+']        1
# ['pi0', 'rho0', 'pi+', 'rho+', 'K+']              1 ['pi0', 'pi0', 'pi+', 'K+', 'K*+', 'D*+', 'h_1'] 1
# ['K+', 'K*+', 'D_s+']                             1 ['K*+', 'D+']                            1
# ['D*+', 'Sigma*+', 'Xi*-']                        1 ['pi+', 'omega', 'K+', 'D0', 'D0']       1
# ['pi0', 'pi0', 'pi0', 'pi0', 'pi+', 'K*+', 'D_s*+']          1 ['rho+', 'K0', 'K*0', 'D*+']             1
# ['gamma', 'gamma', 'pi+', 'pi+', 'pi+', 'D0']          1 ['rho+', 'K0', 'K*0', 'D+']              1
# ['pi0', 'rho0', 'pi+', 'K0', 'D*0']               1 ['pi+', 'pi+', 'pi+', 'eta', 'D*+']      1
# ['K0', 'p+', 'Sigma_c0']                          1 ['Delta0', 'Sigma_c0', 'f_1']            1
# ['rho0', 'pi+', 'eta', 'D0']                      1 ['D+', 'Lambda0', 'Lambda_c+']           1
# ['pi0', 'rho0', 'pi+', 'D_0*0']                   1 ['pi+', 'eta', 'K0', 'K0', 'D+']         1
# ['pi0', 'K+', 'D*+', 'D*+']                       1 ['eta', 'K*0', 'D0', 'D0']               1
# ['pi+', 'K+', 'D0', 'n0', 'Sigma-']               1 ['e-', 'nu_e', 'pi0', 'D+']              1
# ['pi+', 'pi+', 'K0', 'K+', 'D*0']                 1 ['rho+', 'K*0', 'K+', 'h_1']             1
# ['pi0', 'pi+', 'pi+', 'a_2+', 'eta', 'omega', 'D0']          1 ['a_20', 'Delta0', 'Sigma_c*0']          1
# ['pi0', 'pi+', 'eta', 'K0', 'K*0', 'D0']          1 ['pi0', 'pi0', 'pi+', 'eta', 'D+']       1
# ['gamma', 'pi0', 'pi0', 'pi0', 'pi+', 'pi+', 'D+']          1 ['rho0', 'rho+', 'K0', 'K*0', 'D+']      1
# ['rho0', 'K+', 'K*+', 'K*+', 'D0']                1 ['K0', 'K+', 'K+', 'D0']                 1
# ['pi0', 'pi+', 'pi+', 'pi+', 'pi+', 'pi+']          1 ['a_20', 'pi+', 'eta', 'K0', 'D_s+']     1
# ['pi0', 'rho0', 'rho0', 'rho0', 'pi+', 'D*0']          1 ['pi+', 'K0', 'D+']                      1
# ['pi0', 'Delta++', 'Lambda_c+']                   1 ['pi+', 'K*0', 'D+']                     1
# ['pi+', 'pi+', 'K*0', 'D+', 'D*0']                1 ['K0', 'K0', 'D*+', 'D_s+']              1
# ['gamma', 'K+', 'Delta+', 'Sigma_c+']             1 ['pi+', 'pi+', 'pi+', 'K+', 'K+', 'D+']  1
# ['pi0', 'pi0', 'a_20', 'pi+', 'pi+', 'pi+', 'pi+', 'rho+', 'omega']          1 ['rho0', 'rho0', 'rho+', 'D+']           1
# ['K+', 'D*+', 'D_1+']                             1 ['e-', 'nu_e', 'rho+']                   1
# ['pi0', 'K*0', 'D*+', 'D*0']                      1 ['pi+', 'K*0', 'K+', 'D+', 'b_1+']       1
# ['D0', 'Delta0', 'p+']                            1 ['rho+', 'eta', 'K+', 'eta_c']           1
# ['pi+', 'rho+', 'K*+', 'phi', 'D0']               1 ['pi0', 'pi+', 'rho+', 'K0']             1
# ['rho0', 'pi+', 'pi+', 'rho+', 'omega', 'D0']          1 ['pi0', 'D*0']                           1
# ['pi0', 'pi0', 'K+', 'D0', 'D*0']                 1 ['rho+', 'K*+', 'D0', 'D0']              1
# ['pi0', 'K*+', 'D0', 'D*0']                       1 ['rho+', 'K*0', 'K*0', 'D+']             1
# ['pi0', 'pi+', 'pi+', 'pi+', 'D*0']               1 ['pi0', 'D*+', 'D_s*+']                  1
# ['gamma', 'gamma', 'pi+', 'D_10']                 1 ['K0', 'D_s+', 'D_s1+']                  1
# ['K+', 'K+', 'D*0', 'D_s+']                       1 ['pi0', 'pi0', 'rho+', 'K+', 'K+', 'D+'] 1
# ['pi0', 'pi+', 'pi+', 'eta', 'D0', 'a_0+']          1 ['pi0', 'pi0', 'D*+', 'n0', 'p+']        1
# ['rho0', 'K+', 'D+', 'D*+']                       1 ['rho+', 'D*0', 'D_s+']                  1
# ['pi0', 'pi0', 'pi0', 'pi+', 'pi+', 'pi+', 'pi+', 'rho+', 'omega', 'D0']          1 ['a_20', 'pi+', 'pi+', 'D_0*0']          1
# ['D+', 'D*0', 'K_10']                             1 ['pi+', 'pi+', 'pi+', 'eta', 'D+']       1
# ['K*+', 'D_s+', 'D_s+']                           1 ['rho0', 'K_0*0']                        1
# ['rho+', 'D0', 'a_0+', 'b_1+']                    1 ['gamma', 'pi0', 'D*+', 'a_0+']          1
# ['pi+', 'K0', 'chi_c0']                           1 ['rho0', 'rho+', 'D*+']                  1
# ['pi0', 'rho0', 'pi+', 'D*0', 'p+', 'p+']          1 ['pi0', 'rho0', 'pi+', 'pi+', 'pi+', 'rho+', 'D*0', 'a_10'] 1
# ['K+', 'K+', 'K+', 'D0', 'D0']                    1 ['omega', 'K*+', 'D_s+']                 1
# ['pi+', 'pi+', 'K0', 'K+', 'D0']                  1 ['pi+', 'pi+', 'rho+', 'D_0*+']          1
# ['gamma', 'pi0', 'pi+', 'K+', 'phi', 'D+']          1 ['pi+', 'K0', 'K*0', 'D_0*+']            1
# ['pi+', 'eta', 'K*+', 'D*+', 'h_1']               1 ['pi+', 'K+', 'D+', 'D_2*+']             1
# ['rho0', 'pi+', 'pi+', 'rho+', 'eta', 'D0']          1 ['pi0', 'pi+', 'rho+', 'rho+', 'D+']     1
# ['pi+', 'eta', 'K+', 'K+', 'D0']                  1 ['K+', 'D_2*+', 'D0']                    1
# ['rho+', 'K+', 'D+']                              1 ['pi0', 'rho0', 'omega', 'D0']           1
# ['rho0', 'pi+', 'pi+', 'eta', 'omega', 'K0', 'D*+']          1 ['rho+', 'D0', 'D_s*+']                  1
# ['K+', 'phi', 'eta_c']                            1 ['pi0', 'pi+', 'K+', 'chi_c0']           1
# ['tau-', 'nu_tau', 'D_2*0']                       1 ['pi+', 'K+', 'chi_c1']                  1
# ['pi+', 'D0', 'D*0']                              1 ['rho+', 'K+', 'K*+', 'D+']              1
# ['pi+', 'rho+', 'K+', 'K+', 'K+']                 1 ['rho0', 'rho0', 'pi+', 'pi+', 'D*0']    1
# ['pi+', 'K0', 'D0', 'D0']                         1 ['pi+', 'pi+', 'eta', 'omega', 'K0', 'K+', 'D+'] 1
# ['gamma', 'rho+', "D'_10"]                        1 ['rho0', 'D+', 'a_0+']                   1
# ['pi+', 'K0', 'D_s+', 'D_s*+']                    1 ['pi0', 'pi+', 'K+', 'D+', 'p+', 'Lambda0'] 1
# ['pi0', 'pi0', 'D*0', 'b_1+']                     1 ['pi0', 'pi0', 'rho0', 'pi+', 'D*+']     1
# ['rho0', 'K0', 'D*+', 'D*0']                      1 ['pi0', 'pi0', 'pi+', 'pi+', 'pi+', 'D+'] 1
# ['eta', 'K*0', 'K+', 'D_0*0']                     1 ['rho+', 'K0', 'K0', 'K0', 'K*0', 'D+']  1
# ['eta', 'K+', 'D+', 'D+']                         1 ['pi0', 'pi+', 'K+', 'K+', 'D*+']        1
# ['pi0', 'pi+', 'rho+', 'rho+', 'D*0']             1 ['pi0', 'a_2+', 'D+', 'n0', 'n0']        1
# ['pi+', 'K0', 'D+', 'D*+']                        1 ['K0', 'phi', 'D+', 'D+']                1
# ['pi+', 'pi+', 'K+', 'chi_c1']                    1 ['gamma', 'pi0', 'rho0', 'pi+', 'pi+', 'rho+', 'D*+'] 1
# ['tau-', 'nu_tau', 'gamma', 'D*0']                1 ['K+', 'K*+', 'D_s+', 'b_1+']            1
# ['pi0', 'pi0', 'pi+', 'D_10']                     1 ['pi+', 'Sigma*0', 'Xi_c+']              1
# ['rho0', 'pi+', 'pi+', 'pi+', 'omega', 'D0']          1 ['rho0', 'K+', 'D+', 'D0']               1
# ['gamma', 'rho0', 'pi+', 'D*0']                   1 ['gamma', 'pi0', 'pi+', 'pi+', 'K*0', 'K+', 'D+'] 1
# ['K*0', 'Sigma*+', 'Sigma_c*0']                   1 ['Delta+', 'Delta+', 'D_0*0']            1
# ['pi0', 'pi+', 'D*0', 'a_10']                     1 ['pi0', 'pi+', 'pi+', 'pi+', 'rho+', 'rho+', 'D*+'] 1
# ['gamma', 'pi0', 'pi+', 'pi+', 'rho+', 'omega', 'D0']          1 ['pi0', 'pi+', 'K+', 'psi(2S)']          1
# ['rho0', 'pi+', 'pi+', 'K*0', 'K+', 'D*0']          1 ['rho0', 'pi+', 'D*+', 'f_0']            1
# ['Delta-', 'p+', 'D_1+']                          1 ['D_s*+', 'Delta+', 'Sigma0']            1
# ['pi+', 'K0', 'K0', 'D*+', 'D_s+']                1 ['pi0', 'pi+', 'K+', 'K*+', 'D*+']       1
# ['pi+', 'pi+', 'rho+', 'K*0', 'D*0']              1 ['gamma', 'gamma', 'pi+', 'pi+', 'pi+', 'D+'] 1
# ['pi+', 'D_2*0']                                  1 ['gamma', 'pi+', 'pi+', 'K*0', 'D0', 'D*0'] 1
# ['pi0', 'pi0', 'pi+', 'K*0', 'K*0', 'D0']          1 ['pi+', 'K0', 'K*0', 'D*+']              1
# ['K0', 'Delta++', 'Lambda_c+']                    1 ['omega', 'K+', 'D_s+']                  1
# ['Delta0', 'Delta++', "D'_1+"]                    1 ['rho+', 'K*0', 'D+']                    1
# ['gamma', 'pi+', 'pi+', 'pi+', 'D_10']            1 ['gamma', 'rho0', 'K*0', 'K+', 'D*+']    1
# ['rho0', 'D0', 'D_s*+']                           1 ['pi0', 'rho+', 'eta', 'D*+']            1
# ['pi+', 'omega', 'omega', 'D0']                   1 ['K0', 'Sigma*0', 'Sigma_c*0']           1
# ['pi+', 'pi+', 'rho+', 'D_2*0']                   1 ['pi0', 'pi+', 'pi+', 'D0', 'Delta++', 'Delta++'] 1
# ['pi0', 'eta', 'K+', 'D0']                        1 ['rho0', 'K+', 'D*+', 'K_0*0']           1
# ['omega', 'Delta+', 'Sigma_c0']                   1 ['K_S0', 'chi_c1']                       1
# ['eta', 'Delta++', 'Xi_c*+']                      1 ['rho+', 'K+', 'K*+', 'D_0*+']           1
# ['pi+', 'D*0', 'f_0']                             1 ['K*0', 'D_s+', 'D_s*+']                 1
# ['pi0', 'rho0', 'pi+', 'K*+', 'D+']               1 ['rho+', 'n0', 'Xi_c+']                  1
# ['D0', 'n0', 'p+']                                1 ['pi0', 'pi+', 'pi+', 'omega', 'D+', 'a_1+'] 1
# ['pi0', 'pi+', 'p+', 'p+', 'D_10']                1 ['pi0', 'pi+', 'pi+', 'rho+', 'D*+']     1
# ['rho0', 'rho0', 'pi+', 'D0']                     1 ['pi+', 'pi+', 'pi+', 'pi+', 'omega', 'K0', 'K+', 'D+'] 1
# ['pi+', 'K+', 'D*+', 'D0']                        1 ['pi0', 'pi+', 'pi+', 'pi+', 'omega', 'K+', 'K*+', 'D+'] 1
# ['omega', 'K0', 'K+', 'D0']                       1 ['gamma', 'pi+', 'D+', 'f_1']            1
# ['gamma', 'pi0', 'pi+', 'rho+', 'rho+', 'D0']          1 ['K_10', 'psi(2S)']                      1
# ['pi0', 'pi0', 'rho+', 'K+', 'D+']                1 ['K*0', 'p+', 'Sigma_c+']                1
# ['pi+', 'D_0*0']                                  1 ['pi0', 'K*0', 'D+', 'K_1+']             1
# ['gamma', 'pi0', 'pi+', 'pi+', 'pi+', 'D0']          1 ['pi0', 'pi0', 'rho0', 'pi+', 'omega', 'K*0', 'a_0+'] 1
# ['rho+', 'rho+', 'K0', 'D*+', 'f_0']              1 ['K+', 'Delta0', 'Sigma_c+']             1
# ['K*0', 'K+', 'D+', 'a_0+']                       1 ['pi+', 'K+', 'eta_c']                   1
# ['pi0', 'pi0', 'pi0', 'pi+', 'pi+', 'pi+', 'K*+', 'D_s0*+']          1 ['gamma', 'pi+', 'pi+', 'a_2+', 'D+']    1
# ['gamma', 'gamma', 'rho+', 'D0']                  1 ['gamma', 'pi0', 'rho0', 'rho+', 'D*+']  1
# ['pi0', 'Sigma+', "Xi'_c0"]                       1 ['pi0', 'pi0', 'pi+', 'pi+', 'K*0', 'K+', 'D*+'] 1
# ['gamma', 'D*+', 'Delta0', 'Delta++']             1 ['rho0', 'K*0', 'D0', 'D0']              1
# ['pi0', 'pi0', 'pi0', 'rho0', 'pi+', 'D0']          1 ['pi0', 'pi+', 'rho+', 'K*0', 'K+', 'K+'] 1
# ['pi0', 'pi+', "eta'", 'D0']                      1 ['pi0', 'pi+', 'rho+', 'D*0']            1
# ['J/psi', 'n0', 'p+']                             1 ['pi0', 'pi+', 'pi+', "eta'", 'D0', 'D0'] 1
# ['pi+', 'pi+', 'pi+', 'rho+', 'K0', 'K*+', 'D*0']          1 ['gamma', 'pi+', 'rho+', 'D_2*0', 'f_0'] 1
# ['D*0', 'p+', 'Delta++']                          1 ['pi+', 'K0', 'D*+']                     1
# ['gamma', 'pi+', 'pi+', 'rho+', 'D0']             1 ['D+', 'D*+']                            1
# ['rho0', 'Delta++', 'Lambda_c+']                  1 ['rho+', 'K_2*0', 'D+']                  1
# ['gamma', 'pi0', 'K+', 'chi_c1']                  1 ['pi+', 'rho+', 'K*0', 'K+', 'K+', 'D*0'] 1
# ['Delta++', 'Sigma_c+', 'K_0*0']                  1 ['pi+', 'pi+', 'K+', 'D*+', 'D0']        1
# ['e-', 'nu_e', 'gamma', 'pi0', 'D0']              1 ['pi+', 'pi+', 'pi+', 'pi+', 'rho+', 'eta', 'D+', 'f_0'] 1
# ['gamma', 'K+', 'J/psi']                          1 ['pi0', 'K0', 'psi(3770)']               1
# ['p+', 'Delta++', 'D_10']                         1 ['pi0', 'pi+', 'K0', 'K*0', 'D*+']       1
# ['rho+', 'K0', 'K0', 'D*0']                       1 ['pi+', 'K0', 'K*0', 'D+']               1
# ['pi+', 'pi+', 'pi+', 'pi+', 'rho+', 'K0', 'K*0', 'D0']          1 ['pi0', 'pi0', 'pi+', 'rho+', 'f_0']     1
# ['K_2*+', 'J/psi']                                1 ['eta', 'K0', 'K*0', 'K*0']              1
# ['pi0', 'pi0', 'pi+', 'pi+', 'K0', 'K+', 'D0']          1 ['pi0', 'pi0', 'K*0', 'D+', 'D_0*+']     1
# ['pi0', 'pi+', 'pi+', 'K0', 'D*+', 'D0']          1 ['pi0', 'pi0', 'rho+', 'D*+']            1
# ['K*+', 'D_s+', 'D_s*+']                          1 ['pi+', 'pi+', 'K*+', 'D+', 'D*0']       1
# ['pi0', 'pi0', 'pi+', 'D0', 'Delta-', 'Delta-']          1 ['pi0', 'pi0', 'pi0', 'a_20', 'pi+', 'pi+', 'D0'] 1
# ['pi0', 'pi+', 'pi+', 'omega', 'K0', "eta'", 'D*+']          1 ['rho+', 'K+', 'K*+', 'K*+', 'D0']       1
# ['pi0', 'pi+', 'pi+', 'rho+', 'K0', 'K0']          1 ['gamma', 'pi+', 'pi+', 'D*+', 'a_1+']   1
# ['pi+', 'pi+', 'rho+', 'eta', 'D0']               1 ['K0', 'K+', "D'_1+"]                    1
# ['pi+', 'pi+', 'omega', 'K*0', 'K+', 'D0']          1 ['pi0', 'D+', 'n0', 'Lambda_c+']         1
# ['omega', 'K0', 'K+', "D'_10"]                    1 ['omega', 'D+', 'a_0+']                  1
# ['rho+', 'K+', 'D+', 'D0']                        1 ['pi0', 'pi+', 'pi+', 'pi+', 'D+']       1
# ['pi0', 'pi0', 'pi0', 'rho0', 'pi+', 'pi+', 'pi+', 'D0']          1 ['K0', 'K*+', 'D+']                      1
# ['K+', 'Delta++', 'Sigma_c*++']                   1 ['pi+', 'D*+', 'f_1']                    1
# ['pi0', 'pi+', 'pi+', 'eta', 'D+']                1 ['rho0', 'pi+', 'eta', 'D*+']            1
# ['K+', 'K+', 'D0', 'D_s+']                        1 ['n0', 'Delta0', "D'_10"]                1
# ['omega', 'Delta++', 'Sigma_c+']                  1 ['pi0', 'pi+', 'pi+', 'pi+', 'omega', 'D*+'] 1
# ['pi0', 'rho+', 'rho+', 'rho+', 'D0']             1 ['pi0', 'omega', 'K0', 'K0', 'K0', 'phi'] 1
# ['tau-', 'nu_tau', "h'_1"]                        1 ['pi+', 'K0', 'D*+', 'D0']               1
# ['rho+', 'K+', 'K*+', 'D0']                       1 ['K+', 'Lambda0', 'Sigma_c+']            1
# ['pi+', 'K*0', 'chi_c2']                          1 ['K0', 'K*0', 'K*0']                     1
# ['e-', 'nu_e', 'gamma', 'pi0', 'D*0']             1 ['eta', 'K*0', 'D+', 'D+']               1
# ['pi+', 'pi+', 'K0', 'K+', 'D*0', 'f_1']          1 ['pi0', 'D0', 'p+', 'p+']                1
# ['pi0', 'pi+', 'eta', 'D*0']                      1 ['e-', 'nu_e', 'gamma', 'pi+', 'D0']     1
# ['pi0', 'pi0', 'D0', 'D_s+']                      1 ['rho0', 'pi+', 'K+', 'J/psi']           1
# ['pi+', 'K*0', 'D+', 'D*+']                       1 ['K*0', 'K+', 'phi', 'D+']               1
# ['pi0', 'pi+', 'D_2*0']                           1 ['K*+', 'Delta+', 'Sigma_c++']           1
# ["eta'", 'D0', 'a_0+']                            1 ['rho0', 'rho+', 'D_2*+']                1
# ['gamma', 'K*+', 'D*0']                           1 ['gamma', 'rho+', 'K+', 'K*+', 'D+']     1
# ['pi+', 'rho+', 'rho+', 'D*0', 'b_10']            1 ['pi0', 'a_2+', 'D+']                    1
# ['rho0', 'pi+', 'omega', 'omega', 'D0']           1 ['gamma', 'K+', 'D+', 'D*0']             1
# ['pi0', 'pi0', 'rho0', 'pi+', 'pi+', 'pi+', 'eta', 'D_0*0']          1 ['gamma', 'pi+', 'pi+', 'K*0', 'K+', 'D_s+'] 1
# ['pi0', 'pi+', 'pi+', 'K0', 'K+', 'D0']           1 ['pi+', 'D_2*+', 'a_10']                 1
# ['pi+', 'pi+', 'rho+', 'eta', 'D*0']              1 ['rho0', 'pi+', 'pi+', 'pi+', 'omega', 'D*+'] 1
# ['e-', 'nu_e', 'gamma', 'pi+', 'D*+']             1 ['K_L0', 'psi(3770)']                    1
# ['pi0', 'pi+', 'pi+', 'rho+', 'eta', 'D0']          1 ['pi+', 'p+', 'Sigma_c*++']              1
# ['omega', 'eta_c', "K'_1+"]                       1 ['pi+', 'D+', 'D0', 'K_10']              1
# ['pi+', 'pi+', 'rho+', 'K+', 'K+', 'b_10']          1 ['K_S0', 'eta_c']                        1
# ['K*+', 'psi(2S)']                                1 ['K0', 'K+', 'D_1+']                     1
# ['gamma', 'pi+', 'D0', 'n0', 'n0']                1 ['pi0', 'K0', 'D0', 'D0']                1
# ['K*0', 'Delta++', 'Lambda_c+']                   1 ['gamma', 'pi+', 'rho+', 'K*0', 'D*0']   1
# ['Delta++', 'Sigma_c++', 'K_1+']                  1 ['pi+', 'K0', 'K*0', 'D_1+']             1
# ['rho0', 'D_s*+']                                 1 ['pi0', 'rho0', 'rho0', 'pi+', 'D+']     1
# ['Delta++', 'Lambda_c+', 'b_10']                  1 ['gamma', 'pi+', 'pi+', 'pi+', 'K0', 'K*0', 'D+'] 1
# ['gamma', 'rho+', 'Delta++', 'Sigma_c++']          1 ['D0', 'Delta0', 'Delta0']               1
# ['pi0', 'pi+', 'K*0', 'D*0']                      1 ['pi+', 'rho+', 'K+', 'D*+']             1
# ['tau-', 'nu_tau', 'gamma', 'D0']                 1 ['pi0', 'pi+', 'K0', 'K*0', 'D*0', "K'_1+"] 1
# ['K_2*0', 'K+', 'D*0']                            1 ['pi+', "eta'", 'D+', 'D*0']             1
# ['pi+', 'D0', 'a_00']                             1 ['pi+', 'pi+', 'pi+', 'pi+', 'omega', 'D0'] 1
# ['pi+', 'pi+', 'pi+', 'K+', 'D*+', 'D0']          1 ['rho+', 'K+', 'K+', 'D+']               1
# ['pi0', 'pi0', 'pi+', 'pi+', 'pi+', 'rho+', 'rho+', 'D0']          1 ['e-', 'nu_e', 'gamma', 'gamma', 'D_0*+'] 1
# ['pi0', 'pi+', 'K+', 'K+', 'D0']                  1 ['pi0', 'pi0', 'pi+', 'pi+', 'K*0', 'K+', 'D+'] 1
# ['pi0', 'pi+', 'rho+', 'D*+']                     1 ['pi0', 'eta', 'D+', 'D+']               1
# ['pi+', 'K*+', 'D*+', 'D0']                       1 ['pi+', 'eta', 'K+', 'D*+', 'D*+']       1
# ['pi0', 'pi+', 'pi+', 'pi+', 'K*+', 'K*+', 'D0']          1 ['K_2*+', 'p+', "Xi'_c0"]                1
# ['K*+', 'chi_c0']                                 1 ['K0', 'K+', 'D_2*+']                    1
# ['eta', 'K0', 'D+']                               1 ['pi0', 'rho+', 'D_1+']                  1
# ['D+', 'Delta0', 'Delta++']                       1 ['pi0', 'omega', 'D*0']                  1
# ['gamma', 'pi+', 'K+', 'K*+', 'D_10']             1 ['pi+', 'K+', 'D_s+', 'D_s+']            1
# ['gamma', 'pi0', 'pi0', 'pi+', 'pi+', 'pi+', 'pi+', 'rho+', 'D*0']          1 ['omega', 'D*+', 'a_1+']                 1
# ['pi0', 'rho0', 'rho0', 'pi+', 'D*0']             1 ['pi0', 'pi0', 'rho0', 'rho0', 'rho+', 'D*+'] 1
# ['pi0', 'K*0', 'D+', 'D*0']                       1 ['pi0', 'pi+', 'rho+', 'K*0', 'K+', 'D+'] 1
# ['e-', 'nu_e', 'gamma', 'gamma', 'pi0', 'D0']          1 ['pi0', 'pi0', 'rho0', 'K+', 'K+', 'D0'] 1
# ['omega', 'K*0', 'D+']                            1 ['gamma', 'D_s+', "D'_1+"]               1
# ['pi+', 'K0', 'D+', 'D_s*+']                      1 ['gamma', 'pi+', 'omega', 'D+']          1
# ['pi0', 'rho0', 'pi+', 'K+', 'D_s+']              1 ['gamma', 'pi0', 'pi+', 'D+', 'b_10']    1
# ['rho0', 'pi+', 'K*+', 'D_2*+']                   1 ['K*0', 'K+', 'K*+', 'K*+', 'D*+']       1
