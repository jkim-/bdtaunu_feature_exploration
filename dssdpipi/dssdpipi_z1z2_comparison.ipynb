# %% [markdown]
# ## Comparison of PDF shapes between D** signal MC samples

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
from IPython.display import HTML

# %%
HTML('''<script>
code_show=true; 
function code_toggle() {
 if (code_show){
 $('div.input').hide();
 } else {
 $('div.input').show();
 }
 code_show = !code_show
} 
$( document ).ready(code_toggle);
</script>
The raw code for this IPython notebook is by default hidden for easier reading.
To toggle on/off the raw code, click <a href="javascript:code_toggle()">here</a>.''')
# Out:
# <script>
# code_show=true;
# function code_toggle() {
#  if (code_show){
#  $('div.input').hide();
#  } else {
#  $('div.input').show();
#  }
#  code_show = !code_show
# }
# $( document ).ready(code_toggle);
# </script>
# The raw code for this IPython notebook is by default hidden for easier reading.
# To toggle on/off the raw code, click <a href="javascript:code_toggle()">here</a>.

# %%
d1 = np.genfromtxt('d1.csv', skip_header=1, delimiter=',')
d2s = np.genfromtxt('d2s.csv', skip_header=1, delimiter=',')

# %%
plt.figure(figsize=(10,6))
ax = plt.gca()
ax.hist([d1[:,0], d2s[:,0]], bins='auto', normed=True, histtype='step', alpha=0.8,
        label = [r'$B\rightarrow{}D_1(D\pi\pi)l\nu$', r'$B\rightarrow{}D(2S)^{(*)}(D\pi\pi)l\nu$']);
ax.set_xlim([-3.5,0]);
ax.set_title(r'PDFs of Logit($z_1$) for $D_1$ and $D(2S)^{(*)}$ samples', fontsize=24);
ax.set_xlabel(r'Logit($z_1$)', fontsize=20);
ax.legend(prop={'size':15});
ax.tick_params(length=8, width=1, labelsize=16);
ttl = ax.title;
ttl.set_position([.5, 1.05]);

# %%
plt.figure(figsize=(10,6))
ax = plt.gca()
ax.hist([d1[:,1], d2s[:,1]], bins='auto', normed=True, histtype='step', alpha=0.8,
        label = [r'$B\rightarrow{}D_1(D\pi\pi)l\nu$', r'$B\rightarrow{}D(2S)^{(*)}(D\pi\pi)l\nu$']);
ax.set_xlim([-1.5,2]);
ax.set_title(r'PDFs of Logit($z_2$) for $D_1$ and $D(2S)^{(*)}$ samples', fontsize=24);
ax.set_xlabel(r'Logit($z_2$)', fontsize=20);
ax.legend(prop={'size':15});
ax.tick_params(length=8, width=1, labelsize=16);
ttl = ax.title;
ttl.set_position([.5, 1.05]);
